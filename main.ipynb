# %%
from collections import defaultdict
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
import numpy as np

# %%
RESULTS_PATH = "RESULTS/"
SOLVERS = {
    "CLK":"Chained Lin-Kernighan",
    "LKH":"Lin-Kernighan-Helsgaun",
    "CONCORDE":"Concorde",
    "EAX":"Edge Assembly Crossover",
    "MAOS":"Multiagent optimization system"
}

# %%
solvers_data = {}
for SOLVER in SOLVERS.keys():
    solver_data = defaultdict(list)
    for INSTANCE in [f for f in listdir(RESULTS_PATH+SOLVER)]:
        solver_data[INSTANCE]
        f = open(RESULTS_PATH+SOLVER+"/"+INSTANCE, "r")
        for line in f:
            split = line.split()
            if len(split) == 2:
                try:
                    best_value, time = int(split[0]),float(split[1])
                    solver_data[INSTANCE].append((best_value, time))
                except:
                    print(split)
    solvers_data[SOLVER] = solver_data
# Out:
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']
# ['infeas_recover', '...']

# %%
INSTANCE = 'Tnm1000.tsp.out'
fig=plt.figure(figsize=(18, 10), dpi= 80, facecolor='w', edgecolor='k')
for SOLVER in SOLVERS:
    x = np.array(solvers_data[SOLVER][INSTANCE])
    print(SOLVER, len(x))
    plt.plot(x[:,1], x[:,0])

x1,x2,y1,y2 = plt.axis()
limits = (0,10,y1+6350000,y2-134000000)
print(limits)
plt.axis(limits)
plt.show()
# Out:
# CLK 18
# LKH 450
# CONCORDE 1
# EAX 28
# MAOS 29
# (0, 10, 18100354.75, 18263106.25)

# %%
plt.plot(np.array(a)[:,1],np.array(a)[:,0])
